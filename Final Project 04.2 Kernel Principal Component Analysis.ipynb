# %% [markdown]
# ## Kernel Principal Component Analysis

# %% [markdown]
# Group 6
#
# Members (Student ID/Email): Abigail Keller (2026918, akelle30@depaul.edu), Kara Faciszewski (1976775, kfacisze@depaul.edu), Joel Fernandez (1394698, jferna26@depaul.edu), Elizabeth Kerrigan (1994142, ekerrig3@depaul.edu). Srinath V.S. (1979936 , SVANAMAM@depaul.edu)

# %%
#import statements
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Functions

# %%
from sklearn.decomposition import KernelPCA
# Function:    KPCA
# Input:       dataset
# Returns:     top ratios and corresponding feature 
#              names for Kernel Principal Component Analysis
def KPCA(data):
    kpca = KernelPCA(n_components=50, kernel='rbf', n_jobs=-1, remove_zero_eig=True, random_state=0)
    kpca.fit(X)
    X_kpca = kpca.transform(X)
    return X_kpca

# %% [markdown]
# #### Read in the Data

# %%
# Read HR_Employee.csv
X = pd.read_csv('./Data/HR_Employee.csv')
X
# Out:
#            Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyRate  \
# 0     0.547619   0.715820          0.000000    0.914286     0.698053
# 1     0.738095   0.126700          0.250000    0.442857     0.916001
# 2     0.452381   0.909807          0.035714    0.885714     0.012126
# 3     0.357143   0.923407          0.071429    0.371429     0.845814
# 4     0.214286   0.350036          0.035714    0.142857     0.583738
# ...        ...        ...               ...         ...          ...
# 1465  0.428571   0.559771          0.785714    0.157143     0.409396
# 1466  0.500000   0.365784          0.178571    0.171429     0.777474
# 1467  0.214286   0.037938          0.107143    0.814286     0.123670
# 1468  0.738095   0.659270          0.035714    0.471429     0.447661
# 1469  0.380952   0.376521          0.250000    0.742857     0.326601
#
#       NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 0               0.888889           0.000000          0.000000
# ...

# %%
# Testing PrincipalComponentAnalysis Function
X_kpca = pd.DataFrame(KPCA(X))

# %%
X_kpca.shape
# Out:
# (1470, 50)

# %%
X_kpca
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.190471  0.120381  0.168355  0.049146  0.027096 -0.084322  0.075668
# 1    -0.094661 -0.059728 -0.069145 -0.002565 -0.203911  0.000811  0.087605
# 2    -0.094563 -0.029675  0.152808  0.049617 -0.159672  0.130050 -0.071856
# 3    -0.072899  0.156142  0.073559  0.129289 -0.054497 -0.179661 -0.027632
# 4    -0.093230 -0.096261 -0.108137  0.000032  0.019359  0.006988 -0.168582
# ...        ...       ...       ...       ...       ...       ...       ...
# 1465 -0.096460 -0.079932 -0.092359  0.038831 -0.018670  0.094364  0.006950
# 1466 -0.083206 -0.063203 -0.130614  0.014198 -0.105366  0.147707 -0.081994
# 1467 -0.088106 -0.030270 -0.023368  0.127657 -0.146385  0.000518  0.001828
# 1468  0.147723 -0.094428 -0.065939  0.001065  0.060945  0.182308  0.079363
# 1469 -0.105192 -0.087239 -0.164531 -0.003247  0.058039  0.125320 -0.027175
#
# ...

# %% [markdown]
# ### Saving to CSV

# %%
X_kpca.to_csv('./Data/KPCA_HR_Employee.csv', index = False)
